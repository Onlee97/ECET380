# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
    IS_COLAB = True
except Exception:
    IS_COLAB = False

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.test.is_gpu_available():
    print("No GPU was detected. LSTMs and CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
# Out:
# WARNING:tensorflow:From <ipython-input-1-606ac0e8de3d>:21: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# No GPU was detected. LSTMs and CNNs can be very slow without a GPU.

# %% [markdown]
# ## Implementing a simple RNN

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + noise
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None))
save_fig("time_series_plot")
plt.show()
# Out:
# Saving figure time_series_plot

# %% [markdown]
# Basline Metrics Naive predictions (just predict the last observed value):

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.020211367

# %% [markdown]
# Linear predictions:

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 1s 95us/sample - loss: 0.1004 - val_loss: 0.0559
# Epoch 2/20
# 7000/7000 [==============================] - 0s 49us/sample - loss: 0.0386 - val_loss: 0.0269
# Epoch 3/20
# 7000/7000 [==============================] - 0s 49us/sample - loss: 0.0205 - val_loss: 0.0162
# Epoch 4/20
# 7000/7000 [==============================] - 0s 55us/sample - loss: 0.0133 - val_loss: 0.0118
# Epoch 5/20
# 7000/7000 [==============================] - 0s 63us/sample - loss: 0.0104 - val_loss: 0.0098
# Epoch 6/20
# 7000/7000 [==============================] - 0s 43us/sample - loss: 0.0089 - val_loss: 0.0087
# Epoch 7/20
# 7000/7000 [==============================] - 0s 43us/sample - loss: 0.0080 - val_loss: 0.0078
# Epoch 8/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0073 - val_loss: 0.0071
# Epoch 9/20
# 7000/7000 [==============================] - 0s 42us/sample - loss: 0.0066 - val_loss: 0.0065
# Epoch 10/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0061 - val_loss: 0.0061
# Epoch 11/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0058 - val_loss: 0.0058
# Epoch 12/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0054 - val_loss: 0.0055
# Epoch 13/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0052 - val_loss: 0.0052
# Epoch 14/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0050 - val_loss: 0.0049
# Epoch 15/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0048 - val_loss: 0.0047
# Epoch 16/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0046 - val_loss: 0.0046
# Epoch 17/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0045 - val_loss: 0.0045
# Epoch 18/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0044 - val_loss: 0.0046
# Epoch 19/20
# 7000/7000 [==============================] - 0s 40us/sample - loss: 0.0043 - val_loss: 0.0043
# Epoch 20/20
# 7000/7000 [==============================] - 0s 41us/sample - loss: 0.0042 - val_loss: 0.0041

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 0s 35us/sample - loss: 0.0041
# 0.004145485978573561

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# A simple RNN

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

optimizer = keras.optimizers.Adam(lr=0.005)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 4s 589us/sample - loss: 0.0972 - val_loss: 0.0491
# Epoch 2/20
# 7000/7000 [==============================] - 3s 437us/sample - loss: 0.0372 - val_loss: 0.0298
# Epoch 3/20
# 7000/7000 [==============================] - 3s 439us/sample - loss: 0.0255 - val_loss: 0.0220
# Epoch 4/20
# 7000/7000 [==============================] - 3s 438us/sample - loss: 0.0200 - val_loss: 0.0178
# Epoch 5/20
# 7000/7000 [==============================] - 3s 416us/sample - loss: 0.0167 - val_loss: 0.0152
# Epoch 6/20
# 7000/7000 [==============================] - 3s 410us/sample - loss: 0.0147 - val_loss: 0.0135
# Epoch 7/20
# 7000/7000 [==============================] - 3s 411us/sample - loss: 0.0133 - val_loss: 0.0124
# Epoch 8/20
# 7000/7000 [==============================] - 3s 404us/sample - loss: 0.0124 - val_loss: 0.0117
# Epoch 9/20
# 7000/7000 [==============================] - 3s 408us/sample - loss: 0.0119 - val_loss: 0.0113
# Epoch 10/20
# 7000/7000 [==============================] - 3s 405us/sample - loss: 0.0116 - val_loss: 0.0110
# Epoch 11/20
# 7000/7000 [==============================] - 3s 410us/sample - loss: 0.0114 - val_loss: 0.0110
# Epoch 12/20
# 7000/7000 [==============================] - 3s 410us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 7000/7000 [==============================] - 3s 409us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 7000/7000 [==============================] - 3s 407us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 7000/7000 [==============================] - 3s 410us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 16/20
# 7000/7000 [==============================] - 3s 410us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 7000/7000 [==============================] - 3s 408us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 7000/7000 [==============================] - 3s 404us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 19/20
# 7000/7000 [==============================] - 3s 412us/sample - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 7000/7000 [==============================] - 3s 426us/sample - loss: 0.0114 - val_loss: 0.0109

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 0s 144us/sample - loss: 0.0109
# 0.010885455474257469

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ## Deep RNNs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0433 - val_loss: 0.0073
# Epoch 2/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0066 - val_loss: 0.0052
# Epoch 3/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0051 - val_loss: 0.0043
# Epoch 4/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0045 - val_loss: 0.0044
# Epoch 5/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0040 - val_loss: 0.0038
# Epoch 6/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0038 - val_loss: 0.0042
# Epoch 7/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0037 - val_loss: 0.0033
# Epoch 8/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0036 - val_loss: 0.0035
# Epoch 9/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0034 - val_loss: 0.0038
# Epoch 10/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0035 - val_loss: 0.0034
# Epoch 11/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0034 - val_loss: 0.0031
# Epoch 12/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0034 - val_loss: 0.0030
# Epoch 13/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0034 - val_loss: 0.0031
# Epoch 14/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0033 - val_loss: 0.0039
# Epoch 15/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0033 - val_loss: 0.0030
# Epoch 16/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0033 - val_loss: 0.0033
# Epoch 17/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0034 - val_loss: 0.0033
# Epoch 18/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0032 - val_loss: 0.0030
# Epoch 19/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0032 - val_loss: 0.0032
# Epoch 20/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0032 - val_loss: 0.0029

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 1s 362us/sample - loss: 0.0029
# 0.0029341067522764205

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# Make the second SimpleRNN layer return only the last output:

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0221 - val_loss: 0.0053
# Epoch 2/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0043 - val_loss: 0.0037
# Epoch 3/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0035 - val_loss: 0.0032
# Epoch 4/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0033 - val_loss: 0.0032
# Epoch 5/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0032 - val_loss: 0.0030
# Epoch 6/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0031 - val_loss: 0.0030
# Epoch 7/20
# 7000/7000 [==============================] - 7s 984us/sample - loss: 0.0031 - val_loss: 0.0028
# Epoch 8/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0031 - val_loss: 0.0028
# Epoch 9/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0030 - val_loss: 0.0029
# Epoch 10/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0031 - val_loss: 0.0030
# Epoch 11/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0030 - val_loss: 0.0029
# Epoch 12/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 13/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0030 - val_loss: 0.0030
# Epoch 14/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0030 - val_loss: 0.0030
# Epoch 15/20
# 7000/7000 [==============================] - 7s 972us/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 16/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0030 - val_loss: 0.0028
# Epoch 17/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0029 - val_loss: 0.0031
# Epoch 18/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0030 - val_loss: 0.0027
# Epoch 19/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0029 - val_loss: 0.0030
# Epoch 20/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0029 - val_loss: 0.0026

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 1s 308us/sample - loss: 0.0026
# 0.002576804084703326

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# ## Forecasting Several Steps Ahead

# %%
np.random.seed(43) # not 42, as it would give the first series in the train set

series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
save_fig("forecast_ahead_plot")
plt.show()
# Out:
# Saving figure forecast_ahead_plot

# %% [markdown]
# predict the next 10 values one by one:

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %%
X = X_valid
for step_ahead in range(10):
    y_pred_one = model.predict(X)[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:, 0]

# %%
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_pred))
# Out:
# 0.027277272

# %% [markdown]
# compare this performance with some baselines:

# %%
Y_naive_pred = Y_valid[:, -1:]
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_naive_pred))
# Out:
# 0.22278848

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 1s 123us/sample - loss: 0.1348 - val_loss: 0.0610
# Epoch 2/20
# 7000/7000 [==============================] - 0s 57us/sample - loss: 0.0501 - val_loss: 0.0427
# Epoch 3/20
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.0388 - val_loss: 0.0356
# Epoch 4/20
# 7000/7000 [==============================] - 0s 71us/sample - loss: 0.0334 - val_loss: 0.0314
# Epoch 5/20
# 7000/7000 [==============================] - 0s 52us/sample - loss: 0.0299 - val_loss: 0.0286
# Epoch 6/20
# 7000/7000 [==============================] - 0s 49us/sample - loss: 0.0275 - val_loss: 0.0264
# Epoch 7/20
# 7000/7000 [==============================] - 0s 48us/sample - loss: 0.0258 - val_loss: 0.0251
# Epoch 8/20
# 7000/7000 [==============================] - 0s 47us/sample - loss: 0.0245 - val_loss: 0.0237
# Epoch 9/20
# 7000/7000 [==============================] - 0s 48us/sample - loss: 0.0235 - val_loss: 0.0229
# Epoch 10/20
# 7000/7000 [==============================] - 0s 43us/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 11/20
# 7000/7000 [==============================] - 0s 44us/sample - loss: 0.0221 - val_loss: 0.0220
# Epoch 12/20
# 7000/7000 [==============================] - 0s 44us/sample - loss: 0.0216 - val_loss: 0.0212
# Epoch 13/20
# 7000/7000 [==============================] - 0s 45us/sample - loss: 0.0211 - val_loss: 0.0207
# Epoch 14/20
# 7000/7000 [==============================] - 0s 47us/sample - loss: 0.0207 - val_loss: 0.0204
# Epoch 15/20
# 7000/7000 [==============================] - 0s 44us/sample - loss: 0.0203 - val_loss: 0.0203
# Epoch 16/20
# 7000/7000 [==============================] - 0s 46us/sample - loss: 0.0200 - val_loss: 0.0198
# Epoch 17/20
# 7000/7000 [==============================] - 0s 47us/sample - loss: 0.0197 - val_loss: 0.0194
# Epoch 18/20
# 7000/7000 [==============================] - 0s 43us/sample - loss: 0.0194 - val_loss: 0.0192
# Epoch 19/20
# 7000/7000 [==============================] - 0s 44us/sample - loss: 0.0191 - val_loss: 0.0190
# Epoch 20/20
# 7000/7000 [==============================] - 0s 44us/sample - loss: 0.0189 - val_loss: 0.0188

# %% [markdown]
# an RNN that predicts all 10 next values at once:

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0665 - val_loss: 0.0317
# Epoch 2/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0268 - val_loss: 0.0221
# Epoch 3/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0188 - val_loss: 0.0166
# Epoch 4/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0159 - val_loss: 0.0137
# Epoch 5/20
# 7000/7000 [==============================] - 7s 999us/sample - loss: 0.0138 - val_loss: 0.0127
# Epoch 6/20
# 7000/7000 [==============================] - 7s 993us/sample - loss: 0.0132 - val_loss: 0.0117
# Epoch 7/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0119 - val_loss: 0.0117
# Epoch 8/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0115 - val_loss: 0.0119
# Epoch 9/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0110 - val_loss: 0.0113
# Epoch 10/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0111 - val_loss: 0.0097
# Epoch 11/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0104 - val_loss: 0.0098
# Epoch 12/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0100 - val_loss: 0.0092
# Epoch 13/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0101 - val_loss: 0.0101
# Epoch 14/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0100 - val_loss: 0.0103
# Epoch 15/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0097 - val_loss: 0.0092
# Epoch 16/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0094 - val_loss: 0.0088
# Epoch 17/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0091 - val_loss: 0.0088
# Epoch 18/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0091 - val_loss: 0.0081
# Epoch 19/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0089 - val_loss: 0.0079
# Epoch 20/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0088 - val_loss: 0.0081

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# Now let's create an RNN that predicts the next 10 steps at each time step. That is, instead of just forecasting time steps 50 to 59 based on time steps 0 to 49, it will forecast time steps 1 to 10 at time step 0, then time steps 2 to 11 at time step 1, and so on, and finally it will forecast time steps 50 to 59 at the last time step. Notice that the model is causal: when it makes predictions at any time step, it can only see past time steps.

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %%
X_train.shape, Y_train.shape
# Out:
# ((7000, 50, 1), (7000, 50, 10))

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer=keras.optimizers.Adam(lr=0.01), metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0498 - last_time_step_mse: 0.0388 - val_loss: 0.0416 - val_last_time_step_mse: 0.0321
# Epoch 2/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0389 - last_time_step_mse: 0.0281 - val_loss: 0.0331 - val_last_time_step_mse: 0.0225
# Epoch 3/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0325 - last_time_step_mse: 0.0212 - val_loss: 0.0290 - val_last_time_step_mse: 0.0171
# Epoch 4/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0294 - last_time_step_mse: 0.0182 - val_loss: 0.0290 - val_last_time_step_mse: 0.0188
# Epoch 5/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0271 - last_time_step_mse: 0.0152 - val_loss: 0.0272 - val_last_time_step_mse: 0.0148
# Epoch 6/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0246 - last_time_step_mse: 0.0121 - val_loss: 0.0237 - val_last_time_step_mse: 0.0109
# Epoch 7/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0226 - last_time_step_mse: 0.0101 - val_loss: 0.0217 - val_last_time_step_mse: 0.0086
# Epoch 8/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0211 - last_time_step_mse: 0.0084 - val_loss: 0.0198 - val_last_time_step_mse: 0.0072
# Epoch 9/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0204 - last_time_step_mse: 0.0081 - val_loss: 0.0200 - val_last_time_step_mse: 0.0081
# Epoch 10/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0198 - last_time_step_mse: 0.0077 - val_loss: 0.0194 - val_last_time_step_mse: 0.0074
# Epoch 11/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0195 - last_time_step_mse: 0.0074 - val_loss: 0.0190 - val_last_time_step_mse: 0.0069
# Epoch 12/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0192 - last_time_step_mse: 0.0070 - val_loss: 0.0188 - val_last_time_step_mse: 0.0070
# Epoch 13/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0187 - last_time_step_mse: 0.0067 - val_loss: 0.0185 - val_last_time_step_mse: 0.0069
# Epoch 14/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0193 - last_time_step_mse: 0.0075 - val_loss: 0.0180 - val_last_time_step_mse: 0.0063
# Epoch 15/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0190 - last_time_step_mse: 0.0071 - val_loss: 0.0178 - val_last_time_step_mse: 0.0057
# Epoch 16/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0187 - last_time_step_mse: 0.0069 - val_loss: 0.0189 - val_last_time_step_mse: 0.0076
# Epoch 17/20
# 7000/7000 [==============================] - 7s 992us/sample - loss: 0.0187 - last_time_step_mse: 0.0070 - val_loss: 0.0174 - val_last_time_step_mse: 0.0061
# Epoch 18/20
# 7000/7000 [==============================] - 7s 980us/sample - loss: 0.0184 - last_time_step_mse: 0.0068 - val_loss: 0.0175 - val_last_time_step_mse: 0.0060
# Epoch 19/20
# 7000/7000 [==============================] - 7s 979us/sample - loss: 0.0182 - last_time_step_mse: 0.0066 - val_loss: 0.0181 - val_last_time_step_mse: 0.0067
# Epoch 20/20
# 7000/7000 [==============================] - 7s 993us/sample - loss: 0.0180 - last_time_step_mse: 0.0066 - val_loss: 0.0173 - val_last_time_step_mse: 0.0058

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# ## Deep RNN with Batch Norm

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.BatchNormalization(),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.BatchNormalization(),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.1936 - last_time_step_mse: 0.1913 - val_loss: 0.0901 - val_last_time_step_mse: 0.0863
# Epoch 2/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0531 - last_time_step_mse: 0.0441 - val_loss: 0.0559 - val_last_time_step_mse: 0.0469
# Epoch 3/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0470 - last_time_step_mse: 0.0374 - val_loss: 0.0453 - val_last_time_step_mse: 0.0354
# Epoch 4/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0437 - last_time_step_mse: 0.0337 - val_loss: 0.0423 - val_last_time_step_mse: 0.0320
# Epoch 5/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0414 - last_time_step_mse: 0.0310 - val_loss: 0.0402 - val_last_time_step_mse: 0.0301
# Epoch 6/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0390 - last_time_step_mse: 0.0283 - val_loss: 0.0377 - val_last_time_step_mse: 0.0261
# Epoch 7/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0368 - last_time_step_mse: 0.0255 - val_loss: 0.0369 - val_last_time_step_mse: 0.0255
# Epoch 8/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0354 - last_time_step_mse: 0.0240 - val_loss: 0.0369 - val_last_time_step_mse: 0.0244
# Epoch 9/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0342 - last_time_step_mse: 0.0227 - val_loss: 0.0361 - val_last_time_step_mse: 0.0233
# Epoch 10/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0332 - last_time_step_mse: 0.0216 - val_loss: 0.0340 - val_last_time_step_mse: 0.0223
# Epoch 11/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0324 - last_time_step_mse: 0.0210 - val_loss: 0.0338 - val_last_time_step_mse: 0.0229
# Epoch 12/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0316 - last_time_step_mse: 0.0202 - val_loss: 0.0332 - val_last_time_step_mse: 0.0214
# Epoch 13/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0309 - last_time_step_mse: 0.0192 - val_loss: 0.0307 - val_last_time_step_mse: 0.0187
# Epoch 14/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0305 - last_time_step_mse: 0.0189 - val_loss: 0.0322 - val_last_time_step_mse: 0.0198
# Epoch 15/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0304 - last_time_step_mse: 0.0185 - val_loss: 0.0297 - val_last_time_step_mse: 0.0177
# Epoch 16/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0296 - last_time_step_mse: 0.0177 - val_loss: 0.0291 - val_last_time_step_mse: 0.0168
# Epoch 17/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0293 - last_time_step_mse: 0.0173 - val_loss: 0.0285 - val_last_time_step_mse: 0.0163
# Epoch 18/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0288 - last_time_step_mse: 0.0169 - val_loss: 0.0284 - val_last_time_step_mse: 0.0159
# Epoch 19/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0286 - last_time_step_mse: 0.0166 - val_loss: 0.0284 - val_last_time_step_mse: 0.0156
# Epoch 20/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0282 - last_time_step_mse: 0.0162 - val_loss: 0.0323 - val_last_time_step_mse: 0.0214

# %% [markdown]
# ## Deep RNNs with Layer Norm

# %%
from tensorflow.keras.layers import LayerNormalization

# %%
class LNSimpleRNNCell(keras.layers.Layer):
    def __init__(self, units, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units,
                                                          activation=None)
        self.layer_norm = LayerNormalization()
        self.activation = keras.activations.get(activation)
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        if inputs is not None:
            batch_size = tf.shape(inputs)[0]
            dtype = inputs.dtype
        return [tf.zeros([batch_size, self.state_size], dtype=dtype)]
    def call(self, inputs, states):
        outputs, new_states = self.simple_rnn_cell(inputs, states)
        norm_outputs = self.activation(self.layer_norm(outputs))
        return norm_outputs, [norm_outputs]

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True,
                     input_shape=[None, 1]),
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 17s 2ms/sample - loss: 0.1597 - last_time_step_mse: 0.1524 - val_loss: 0.0727 - val_last_time_step_mse: 0.0676
# Epoch 2/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0634 - last_time_step_mse: 0.0567 - val_loss: 0.0568 - val_last_time_step_mse: 0.0500
# Epoch 3/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0540 - last_time_step_mse: 0.0466 - val_loss: 0.0500 - val_last_time_step_mse: 0.0425
# Epoch 4/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0467 - last_time_step_mse: 0.0376 - val_loss: 0.0427 - val_last_time_step_mse: 0.0327
# Epoch 5/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0416 - last_time_step_mse: 0.0311 - val_loss: 0.0389 - val_last_time_step_mse: 0.0282
# Epoch 6/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0379 - last_time_step_mse: 0.0265 - val_loss: 0.0361 - val_last_time_step_mse: 0.0243
# Epoch 7/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0361 - last_time_step_mse: 0.0246 - val_loss: 0.0346 - val_last_time_step_mse: 0.0233
# Epoch 8/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0344 - last_time_step_mse: 0.0226 - val_loss: 0.0337 - val_last_time_step_mse: 0.0217
# Epoch 9/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0334 - last_time_step_mse: 0.0216 - val_loss: 0.0341 - val_last_time_step_mse: 0.0226
# Epoch 10/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0326 - last_time_step_mse: 0.0209 - val_loss: 0.0319 - val_last_time_step_mse: 0.0207
# Epoch 11/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0319 - last_time_step_mse: 0.0202 - val_loss: 0.0307 - val_last_time_step_mse: 0.0194
# Epoch 12/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0310 - last_time_step_mse: 0.0191 - val_loss: 0.0306 - val_last_time_step_mse: 0.0190
# Epoch 13/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0305 - last_time_step_mse: 0.0185 - val_loss: 0.0296 - val_last_time_step_mse: 0.0173
# Epoch 14/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0303 - last_time_step_mse: 0.0181 - val_loss: 0.0303 - val_last_time_step_mse: 0.0184
# Epoch 15/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0296 - last_time_step_mse: 0.0173 - val_loss: 0.0293 - val_last_time_step_mse: 0.0170
# Epoch 16/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0290 - last_time_step_mse: 0.0166 - val_loss: 0.0286 - val_last_time_step_mse: 0.0169
# Epoch 17/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0284 - last_time_step_mse: 0.0160 - val_loss: 0.0289 - val_last_time_step_mse: 0.0164
# Epoch 18/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0282 - last_time_step_mse: 0.0159 - val_loss: 0.0280 - val_last_time_step_mse: 0.0150
# Epoch 19/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0277 - last_time_step_mse: 0.0150 - val_loss: 0.0272 - val_last_time_step_mse: 0.0142
# Epoch 20/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0271 - last_time_step_mse: 0.0145 - val_loss: 0.0266 - val_last_time_step_mse: 0.0138

# %% [markdown]
# ## Creating a Custom RNN Class

# %%
class MyRNN(keras.layers.Layer):
    def __init__(self, cell, return_sequences=False, **kwargs):
        super().__init__(**kwargs)
        self.cell = cell
        self.return_sequences = return_sequences
        self.get_initial_state = getattr(
            self.cell, "get_initial_state", self.fallback_initial_state)
    def fallback_initial_state(self, inputs):
        return [tf.zeros([self.cell.state_size], dtype=inputs.dtype)]
    @tf.function
    def call(self, inputs):
        states = self.get_initial_state(inputs)
        n_steps = tf.shape(inputs)[1]
        if self.return_sequences:
            sequences = tf.TensorArray(inputs.dtype, size=n_steps)
        outputs = tf.zeros(shape=[n_steps, self.cell.output_size], dtype=inputs.dtype)
        for step in tf.range(n_steps):
            outputs, states = self.cell(inputs[:, step], states)
            if self.return_sequences:
                sequences = sequences.write(step, outputs)
        if self.return_sequences:
            return sequences.stack()
        else:
            return outputs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    MyRNN(LNSimpleRNNCell(20), return_sequences=True,
          input_shape=[None, 1]),
    MyRNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.2191 - last_time_step_mse: 0.2068 - val_loss: 0.0863 - val_last_time_step_mse: 0.0750
# Epoch 2/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0718 - last_time_step_mse: 0.0601 - val_loss: 0.0626 - val_last_time_step_mse: 0.0509
# Epoch 3/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0572 - last_time_step_mse: 0.0440 - val_loss: 0.0529 - val_last_time_step_mse: 0.0379
# Epoch 4/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0497 - last_time_step_mse: 0.0358 - val_loss: 0.0476 - val_last_time_step_mse: 0.0324
# Epoch 5/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0454 - last_time_step_mse: 0.0311 - val_loss: 0.0439 - val_last_time_step_mse: 0.0291
# Epoch 6/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0426 - last_time_step_mse: 0.0284 - val_loss: 0.0417 - val_last_time_step_mse: 0.0274
# Epoch 7/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0403 - last_time_step_mse: 0.0263 - val_loss: 0.0391 - val_last_time_step_mse: 0.0252
# Epoch 8/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0384 - last_time_step_mse: 0.0247 - val_loss: 0.0373 - val_last_time_step_mse: 0.0234
# Epoch 9/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0363 - last_time_step_mse: 0.0225 - val_loss: 0.0353 - val_last_time_step_mse: 0.0221
# Epoch 10/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0351 - last_time_step_mse: 0.0213 - val_loss: 0.0338 - val_last_time_step_mse: 0.0196
# Epoch 11/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0332 - last_time_step_mse: 0.0194 - val_loss: 0.0322 - val_last_time_step_mse: 0.0186
# Epoch 12/20
# 7000/7000 [==============================] - 4213s 602ms/sample - loss: 0.0319 - last_time_step_mse: 0.0183 - val_loss: 0.0316 - val_last_time_step_mse: 0.0182
# Epoch 13/20
# 7000/7000 [==============================] - 564s 81ms/sample - loss: 0.0310 - last_time_step_mse: 0.0176 - val_loss: 0.0302 - val_last_time_step_mse: 0.0166
# Epoch 14/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0302 - last_time_step_mse: 0.0168 - val_loss: 0.0297 - val_last_time_step_mse: 0.0164
# Epoch 15/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0296 - last_time_step_mse: 0.0165 - val_loss: 0.0290 - val_last_time_step_mse: 0.0160
# Epoch 16/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0292 - last_time_step_mse: 0.0163 - val_loss: 0.0304 - val_last_time_step_mse: 0.0209
# Epoch 17/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0291 - last_time_step_mse: 0.0162 - val_loss: 0.0288 - val_last_time_step_mse: 0.0161
# Epoch 18/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0286 - last_time_step_mse: 0.0161 - val_loss: 0.0289 - val_last_time_step_mse: 0.0159
# Epoch 19/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0283 - last_time_step_mse: 0.0155 - val_loss: 0.0277 - val_last_time_step_mse: 0.0147
# Epoch 20/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0279 - last_time_step_mse: 0.0153 - val_loss: 0.0278 - val_last_time_step_mse: 0.0148

# %% [markdown]
# ## LSTMs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 15s 2ms/sample - loss: 0.0760 - last_time_step_mse: 0.0615 - val_loss: 0.0554 - val_last_time_step_mse: 0.0372
# Epoch 2/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0480 - last_time_step_mse: 0.0281 - val_loss: 0.0423 - val_last_time_step_mse: 0.0211
# Epoch 3/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0390 - last_time_step_mse: 0.0182 - val_loss: 0.0371 - val_last_time_step_mse: 0.0164
# Epoch 4/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0350 - last_time_step_mse: 0.0151 - val_loss: 0.0335 - val_last_time_step_mse: 0.0143
# Epoch 5/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0325 - last_time_step_mse: 0.0136 - val_loss: 0.0314 - val_last_time_step_mse: 0.0124
# Epoch 6/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0308 - last_time_step_mse: 0.0123 - val_loss: 0.0297 - val_last_time_step_mse: 0.0108
# Epoch 7/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0297 - last_time_step_mse: 0.0117 - val_loss: 0.0289 - val_last_time_step_mse: 0.0106
# Epoch 8/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0286 - last_time_step_mse: 0.0108 - val_loss: 0.0279 - val_last_time_step_mse: 0.0103
# Epoch 9/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0280 - last_time_step_mse: 0.0106 - val_loss: 0.0279 - val_last_time_step_mse: 0.0111
# Epoch 10/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0274 - last_time_step_mse: 0.0105 - val_loss: 0.0270 - val_last_time_step_mse: 0.0103
# Epoch 11/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0268 - last_time_step_mse: 0.0100 - val_loss: 0.0264 - val_last_time_step_mse: 0.0097
# Epoch 12/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0264 - last_time_step_mse: 0.0099 - val_loss: 0.0263 - val_last_time_step_mse: 0.0108
# Epoch 13/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0259 - last_time_step_mse: 0.0096 - val_loss: 0.0257 - val_last_time_step_mse: 0.0094
# Epoch 14/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0257 - last_time_step_mse: 0.0096 - val_loss: 0.0264 - val_last_time_step_mse: 0.0110
# Epoch 15/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0253 - last_time_step_mse: 0.0095 - val_loss: 0.0253 - val_last_time_step_mse: 0.0096
# Epoch 16/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0250 - last_time_step_mse: 0.0092 - val_loss: 0.0248 - val_last_time_step_mse: 0.0091
# Epoch 17/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0247 - last_time_step_mse: 0.0092 - val_loss: 0.0245 - val_last_time_step_mse: 0.0087
# Epoch 18/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0245 - last_time_step_mse: 0.0092 - val_loss: 0.0242 - val_last_time_step_mse: 0.0092
# Epoch 19/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0242 - last_time_step_mse: 0.0089 - val_loss: 0.0237 - val_last_time_step_mse: 0.0084
# Epoch 20/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0239 - last_time_step_mse: 0.0089 - val_loss: 0.0240 - val_last_time_step_mse: 0.0086

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 2000/2000 [==============================] - 1s 358us/sample - loss: 0.0240 - last_time_step_mse: 0.0086
# [0.024016652897000314, 0.008551411]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [raw]
# ## GRUs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 17s 2ms/sample - loss: 0.0742 - last_time_step_mse: 0.0663 - val_loss: 0.0523 - val_last_time_step_mse: 0.0421
# Epoch 2/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0476 - last_time_step_mse: 0.0367 - val_loss: 0.0441 - val_last_time_step_mse: 0.0327
# Epoch 3/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0418 - last_time_step_mse: 0.0305 - val_loss: 0.0391 - val_last_time_step_mse: 0.0271
# Epoch 4/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0373 - last_time_step_mse: 0.0249 - val_loss: 0.0343 - val_last_time_step_mse: 0.0205
# Epoch 5/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0327 - last_time_step_mse: 0.0179 - val_loss: 0.0313 - val_last_time_step_mse: 0.0158
# Epoch 6/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0308 - last_time_step_mse: 0.0155 - val_loss: 0.0297 - val_last_time_step_mse: 0.0143
# Epoch 7/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0296 - last_time_step_mse: 0.0146 - val_loss: 0.0290 - val_last_time_step_mse: 0.0140
# Epoch 8/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0284 - last_time_step_mse: 0.0134 - val_loss: 0.0278 - val_last_time_step_mse: 0.0128
# Epoch 9/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0278 - last_time_step_mse: 0.0131 - val_loss: 0.0278 - val_last_time_step_mse: 0.0133
# Epoch 10/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0272 - last_time_step_mse: 0.0126 - val_loss: 0.0272 - val_last_time_step_mse: 0.0139
# Epoch 11/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0267 - last_time_step_mse: 0.0122 - val_loss: 0.0269 - val_last_time_step_mse: 0.0123
# Epoch 12/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0264 - last_time_step_mse: 0.0121 - val_loss: 0.0267 - val_last_time_step_mse: 0.0132
# Epoch 13/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0260 - last_time_step_mse: 0.0117 - val_loss: 0.0259 - val_last_time_step_mse: 0.0120
# Epoch 14/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0257 - last_time_step_mse: 0.0116 - val_loss: 0.0265 - val_last_time_step_mse: 0.0132
# Epoch 15/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0255 - last_time_step_mse: 0.0116 - val_loss: 0.0256 - val_last_time_step_mse: 0.0119
# Epoch 16/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0252 - last_time_step_mse: 0.0112 - val_loss: 0.0249 - val_last_time_step_mse: 0.0110
# Epoch 17/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0249 - last_time_step_mse: 0.0111 - val_loss: 0.0246 - val_last_time_step_mse: 0.0107
# Epoch 18/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0248 - last_time_step_mse: 0.0112 - val_loss: 0.0251 - val_last_time_step_mse: 0.0124
# Epoch 19/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0244 - last_time_step_mse: 0.0108 - val_loss: 0.0241 - val_last_time_step_mse: 0.0104
# Epoch 20/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0242 - last_time_step_mse: 0.0106 - val_loss: 0.0241 - val_last_time_step_mse: 0.0103

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 2000/2000 [==============================] - 1s 366us/sample - loss: 0.0241 - last_time_step_mse: 0.0103
# [0.024071003958582877, 0.010298318]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# ## Using One-Dimensional Convolutional Layers to Process Sequence

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid",
                        input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train[:, 3::2], epochs=20,
                    validation_data=(X_valid, Y_valid[:, 3::2]))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0683 - last_time_step_mse: 0.0605 - val_loss: 0.0482 - val_last_time_step_mse: 0.0405
# Epoch 2/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0416 - last_time_step_mse: 0.0342 - val_loss: 0.0368 - val_last_time_step_mse: 0.0283
# Epoch 3/20
# 7000/7000 [==============================] - 7s 985us/sample - loss: 0.0334 - last_time_step_mse: 0.0251 - val_loss: 0.0307 - val_last_time_step_mse: 0.0220
# Epoch 4/20
# 7000/7000 [==============================] - 7s 975us/sample - loss: 0.0273 - last_time_step_mse: 0.0172 - val_loss: 0.0251 - val_last_time_step_mse: 0.0141
# Epoch 5/20
# 7000/7000 [==============================] - 7s 982us/sample - loss: 0.0243 - last_time_step_mse: 0.0134 - val_loss: 0.0238 - val_last_time_step_mse: 0.0128
# Epoch 6/20
# 7000/7000 [==============================] - 7s 974us/sample - loss: 0.0230 - last_time_step_mse: 0.0121 - val_loss: 0.0226 - val_last_time_step_mse: 0.0116
# Epoch 7/20
# 7000/7000 [==============================] - 7s 960us/sample - loss: 0.0224 - last_time_step_mse: 0.0116 - val_loss: 0.0220 - val_last_time_step_mse: 0.0110
# Epoch 8/20
# 7000/7000 [==============================] - 7s 967us/sample - loss: 0.0218 - last_time_step_mse: 0.0111 - val_loss: 0.0216 - val_last_time_step_mse: 0.0107
# Epoch 9/20
# 7000/7000 [==============================] - 7s 955us/sample - loss: 0.0214 - last_time_step_mse: 0.0107 - val_loss: 0.0211 - val_last_time_step_mse: 0.0103
# Epoch 10/20
# 7000/7000 [==============================] - 7s 957us/sample - loss: 0.0211 - last_time_step_mse: 0.0105 - val_loss: 0.0209 - val_last_time_step_mse: 0.0102
# Epoch 11/20
# 7000/7000 [==============================] - 7s 962us/sample - loss: 0.0207 - last_time_step_mse: 0.0103 - val_loss: 0.0206 - val_last_time_step_mse: 0.0099
# Epoch 12/20
# 7000/7000 [==============================] - 7s 964us/sample - loss: 0.0206 - last_time_step_mse: 0.0102 - val_loss: 0.0203 - val_last_time_step_mse: 0.0097
# Epoch 13/20
# 7000/7000 [==============================] - 7s 946us/sample - loss: 0.0202 - last_time_step_mse: 0.0098 - val_loss: 0.0200 - val_last_time_step_mse: 0.0095
# Epoch 14/20
# 7000/7000 [==============================] - 7s 944us/sample - loss: 0.0200 - last_time_step_mse: 0.0096 - val_loss: 0.0207 - val_last_time_step_mse: 0.0105
# Epoch 15/20
# 7000/7000 [==============================] - 7s 968us/sample - loss: 0.0197 - last_time_step_mse: 0.0095 - val_loss: 0.0198 - val_last_time_step_mse: 0.0093
# Epoch 16/20
# 7000/7000 [==============================] - 7s 965us/sample - loss: 0.0194 - last_time_step_mse: 0.0091 - val_loss: 0.0191 - val_last_time_step_mse: 0.0087
# Epoch 17/20
# 7000/7000 [==============================] - 7s 957us/sample - loss: 0.0191 - last_time_step_mse: 0.0089 - val_loss: 0.0188 - val_last_time_step_mse: 0.0085
# Epoch 18/20
# 7000/7000 [==============================] - 7s 953us/sample - loss: 0.0187 - last_time_step_mse: 0.0085 - val_loss: 0.0183 - val_last_time_step_mse: 0.0077
# Epoch 19/20
# 7000/7000 [==============================] - 7s 959us/sample - loss: 0.0181 - last_time_step_mse: 0.0078 - val_loss: 0.0178 - val_last_time_step_mse: 0.0074
# Epoch 20/20
# 7000/7000 [==============================] - 7s 960us/sample - loss: 0.0175 - last_time_step_mse: 0.0072 - val_loss: 0.0173 - val_last_time_step_mse: 0.0067

# %% [markdown]
# ## WaveNet

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 4s 619us/sample - loss: 0.0684 - last_time_step_mse: 0.0550 - val_loss: 0.0387 - val_last_time_step_mse: 0.0248
# Epoch 2/20
# 7000/7000 [==============================] - 3s 406us/sample - loss: 0.0341 - last_time_step_mse: 0.0216 - val_loss: 0.0307 - val_last_time_step_mse: 0.0182
# Epoch 3/20
# 7000/7000 [==============================] - 3s 428us/sample - loss: 0.0293 - last_time_step_mse: 0.0172 - val_loss: 0.0275 - val_last_time_step_mse: 0.0152
# Epoch 4/20
# 7000/7000 [==============================] - 3s 409us/sample - loss: 0.0270 - last_time_step_mse: 0.0149 - val_loss: 0.0259 - val_last_time_step_mse: 0.0139
# Epoch 5/20
# 7000/7000 [==============================] - 3s 421us/sample - loss: 0.0253 - last_time_step_mse: 0.0133 - val_loss: 0.0246 - val_last_time_step_mse: 0.0123
# Epoch 6/20
# 7000/7000 [==============================] - 3s 415us/sample - loss: 0.0244 - last_time_step_mse: 0.0125 - val_loss: 0.0237 - val_last_time_step_mse: 0.0116
# Epoch 7/20
# 7000/7000 [==============================] - 3s 425us/sample - loss: 0.0236 - last_time_step_mse: 0.0117 - val_loss: 0.0231 - val_last_time_step_mse: 0.0112
# Epoch 8/20
# 7000/7000 [==============================] - 3s 425us/sample - loss: 0.0231 - last_time_step_mse: 0.0114 - val_loss: 0.0229 - val_last_time_step_mse: 0.0112
# Epoch 9/20
# 7000/7000 [==============================] - 3s 411us/sample - loss: 0.0228 - last_time_step_mse: 0.0112 - val_loss: 0.0223 - val_last_time_step_mse: 0.0106
# Epoch 10/20
# 7000/7000 [==============================] - 3s 409us/sample - loss: 0.0224 - last_time_step_mse: 0.0108 - val_loss: 0.0222 - val_last_time_step_mse: 0.0104
# Epoch 11/20
# 7000/7000 [==============================] - 3s 412us/sample - loss: 0.0219 - last_time_step_mse: 0.0102 - val_loss: 0.0217 - val_last_time_step_mse: 0.0099
# Epoch 12/20
# 7000/7000 [==============================] - 3s 425us/sample - loss: 0.0217 - last_time_step_mse: 0.0101 - val_loss: 0.0220 - val_last_time_step_mse: 0.0103
# Epoch 13/20
# 7000/7000 [==============================] - 3s 421us/sample - loss: 0.0215 - last_time_step_mse: 0.0100 - val_loss: 0.0213 - val_last_time_step_mse: 0.0097
# Epoch 14/20
# 7000/7000 [==============================] - 3s 423us/sample - loss: 0.0214 - last_time_step_mse: 0.0098 - val_loss: 0.0212 - val_last_time_step_mse: 0.0094
# Epoch 15/20
# 7000/7000 [==============================] - 3s 416us/sample - loss: 0.0212 - last_time_step_mse: 0.0097 - val_loss: 0.0209 - val_last_time_step_mse: 0.0094
# Epoch 16/20
# 7000/7000 [==============================] - 3s 430us/sample - loss: 0.0209 - last_time_step_mse: 0.0093 - val_loss: 0.0209 - val_last_time_step_mse: 0.0093
# Epoch 17/20
# 7000/7000 [==============================] - 3s 427us/sample - loss: 0.0207 - last_time_step_mse: 0.0092 - val_loss: 0.0206 - val_last_time_step_mse: 0.0091
# Epoch 18/20
# 7000/7000 [==============================] - 3s 417us/sample - loss: 0.0206 - last_time_step_mse: 0.0090 - val_loss: 0.0204 - val_last_time_step_mse: 0.0091
# Epoch 19/20
# 7000/7000 [==============================] - 3s 428us/sample - loss: 0.0206 - last_time_step_mse: 0.0091 - val_loss: 0.0200 - val_last_time_step_mse: 0.0085
# Epoch 20/20
# 7000/7000 [==============================] - 3s 419us/sample - loss: 0.0202 - last_time_step_mse: 0.0086 - val_loss: 0.0203 - val_last_time_step_mse: 0.0087
